# %%
import cv2


red_flower = cv2.imread('1.jpg')
yellow_flower = cv2.imread('2.jpg')
yellow_bird = cv2.imread('3.jpg')
pink_flower=cv2.imread('4.jpg')
white_flower=cv2.imread('5.jpg')

print(type(red_flower))
# print(src1)
# Out:
# <class 'numpy.ndarray'>

# %%
import numpy as np

red_flower = red_flower.tolist()
yellow_flower = yellow_flower.tolist()
yellow_bird = yellow_bird.tolist() # nested lists with same data, indices
pink_flower=pink_flower.tolist()
white_flower=white_flower.tolist()

# %%
import json
data = {"red_flower":red_flower, "yellow_flower":yellow_flower, "yellow_bird":yellow_bird,'pink_flower':pink_flower,'white_flower':white_flower}

a_file = open("data.json", "w")
a_file = json.dump(data, a_file)



a_file = open("data.json", "r")
a_dictionary = json.load(a_file)

# %%
print(a_dictionary['a'])
# Out:
# [[[5, 27, 15], [7, 29, 17], [8, 32, 20], [12, 36, 24], [15, 41, 28], [17, 45, 32], [20, 48, 35], [20, 50, 37], [14, 46, 35], [14, 44, 33], [13, 37, 29], [11, 32, 24], [9, 23, 19], [8, 16, 15], [6, 11, 10], [6, 8, 8], [13, 7, 12], [13, 7, 12], [12, 9, 11], [12, 9, 11], [11, 11, 11], [10, 13, 11], [11, 14, 12], [11, 14, 12], [4, 12, 5], [6, 14, 7], [8, 19, 9], [13, 24, 14], [16, 30, 18], [19, 36, 22], [22, 41, 26], [24, 43, 28], [28, 46, 29], [29, 48, 31], [30, 54, 36], [30, 60, 41], [30, 67, 47], [31, 74, 53], [32, 79, 57], [31, 83, 60], [39, 92, 65], [38, 86, 62], [36, 77, 56], [41, 70, 54], [49, 67, 54], [53, 62, 52], [53, 53, 47], [49, 46, 42], [62, 30, 35], [59, 27, 32], [55, 21, 27], [52, 16, 22], [53, 12, 19], [53, 11, 18], [54, 10, 17], [55, 11, 18], [56, 12, 19], [56, 12, 19], [58, 11, 19], [59, 12, 20], [61, 12, 20], [62, 13, 21], [64, 13, 21], [64, 13, 21], [74, 20, 37], [67, 17, 21], [54, 11, 8], [51, 5, 11], [52, 3, 25], [59, 6, 33], [64, 12, 29], [66, 17, 19], [64, 10, 27
# ...

# %%
import numpy as np

red_flower = np.asarray(a_dictionary['a'])
yellow_flower = np.asarray(a_dictionary['b'])
yellow_bird = np.asarray(a_dictionary['c'])
pink_flower=np.asarray(a_dictionary['d'])
white_flower=np.asarray(a_dictionary['e'])
# # printing my_array
# print (my_array)
# # # printing the type of my_array
# # print (type(my_array))

# %%
import cv2


cv2.imwrite('red_flower.jpg',red_flower)
cv2.imwrite('yellow_flower.jpg',yellow_flower)
cv2.imwrite('yellow_bird.jpg',yellow_bird)
cv2.imwrite('pink_flower.jpg',pink_flower)
cv2.imwrite('white_flower.jpg',white_flower)
#cv2.imwrite('yellow b',bird)
#cv2.waitkey(0)
#cv2.destroyAllWindows(0)
# Out:
# True

# %%
img=cv2.imread('red_flower.jpg')
cv2.imshow('img',img)
